# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
airline_data = pd.read_excel('EastWestAirlines.xlsx', sheet_name=1)
airline_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_data.shape
# Out:
# (3999, 12)

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline_data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
x = airline_data.drop(labels='ID#',axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x1 = scaler.fit_transform(x)

# %%
x1
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %% [markdown]
# ### Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as sch

# %%
linkage = sch.linkage(x1,method='ward')
plt.figure(figsize=(15,10))
dendrogram = sch.dendrogram(linkage)

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hc=AgglomerativeClustering(n_clusters=3)

# %%
y_hc = hc.fit_predict(x1)

# %%
Clusters = pd.DataFrame(y_hc,columns=['Clusters'])

# %%
Clusters
# Out:
#       Clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            1
# ...        ...
# 3994         0
# 3995         0
# 3996         1
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
airline_data['Clusters'] = Clusters

# %%
airline_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Clusters
# 0         0
# 1         0
# ...

# %%
airline_data.sort_values('Clusters')
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 2524  2543     4923           0          1          1          1          305
# 2527  2546    45149           0          1          1          1        21292
# 2528  2547    57477           0          1          1          1         2607
# 2529  2548    48265           0          1          1          1         1000
# ...    ...      ...         ...        ...        ...        ...          ...
# 2747  2769    95759           0          1          1          1         9198
# 611    619   179042           0          1          1          1        25078
# 839    850   119932           0          3          1          1        22463
# 2153  2170   184301           0          1          1          1         6454
# 3594  3617    27619           0          4          1          1        83726
#
# ...

# %%
clus_analys = airline_data.groupby('Clusters').mean()

# %%
clus_analys
# Out:
#                   ID#        Balance  Qual_miles  cc1_miles  cc2_miles  \
# Clusters
# 0         2198.450783   46718.863399    9.274407   1.242266   1.023303
# 1         1707.093478  116314.450725  363.839130   3.498551   1.000000
# 2         1765.615385  134880.892308  393.323077   2.430769   1.000000
#
#           cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# Clusters
# 0          1.000000   5037.792688     7.091201         221.167135
# 1          1.035507  37150.356522    18.066667         377.000000
# 2          1.000000  36582.169231    29.338462        5915.523077
#
#           Flight_trans_12  Days_since_enroll    Award?
# Clusters
# 0                0.700281        3772.785858  0.188027
# 1                1.150000        4696.888406  0.663043
# 2               16.638462        4599.607692  0.753846

# %%
plt.figure(figsize=(5,5))  
plt.scatter(x1[:,0], x1[:,1], c= hc.labels_)

# %% [markdown]
# # K - Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(x1)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
clusters = KMeans(n_clusters=3,random_state=123)

# %%
clusters.fit(x1)
# Out:
# KMeans(n_clusters=3, random_state=123)

# %%
clusters.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
airline_data['Clusters'] = clusters.labels_

# %%
airline_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Clusters
# 0         0
# 1         0
# ...

# %%
airline_data.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                    mean           mean        mean      mean      mean
# 0        0  2235.212262   44370.730307   96.720605  1.237097  1.019014
# 1        1  1601.309221  117627.582671  157.884738  3.732114  1.002385
# 2        2  1723.621951  195200.231707  783.207317  2.152439  1.036585
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.000388   4837.902212    7.015134        200.463718        0.625534
# 1  1.038156  40499.723370   18.991256        346.263911        1.025437
# 2  1.000000  31379.963415   26.993902       5412.000000       15.798780
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       3707.357004  0.204501
# 1       4883.024642  0.652623
# 2       4715.945122  0.810976

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
dbs = DBSCAN(eps=1,min_samples=9)

# %%
dbs.fit(x1)
# Out:
# DBSCAN(eps=1, min_samples=9)

# %%
dbs.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
airline_data['Clusters'] = dbs.labels_

# %%
airline_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Clusters
# 0         0
# 1         0
# ...

# %%
airline_data.groupby('Clusters').agg(['mean']).reset_index()
# Out:
#   Clusters          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                    mean           mean        mean      mean      mean
# 0       -1  1725.998476  173941.010671  859.234756  2.670732  1.071646
# 1        0  2186.053392   52284.891466    2.463895  1.652079  1.000000
# 2        1  1813.368672   57730.095511    6.710602  2.576886  1.000000
# 3        2  2843.545455   28365.363636    0.000000  1.000000  2.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.074695  37699.176829   21.062500       2024.500000        5.855183
# 1  1.000000   8929.385120    8.366740        108.642888        0.362363
# 2  1.000000  22283.531041   12.732569        251.377268        0.785100
# 3  1.000000   8825.272727   11.818182         22.727273        0.181818
#
#   Days_since_enroll    Award?
#                mean      mean
# 0       4683.217988  0.661585
# ...
